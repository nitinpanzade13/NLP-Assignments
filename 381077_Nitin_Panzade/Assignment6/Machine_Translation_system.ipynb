# %% [markdown]
# # **6. Develop a Machine Translation system to translate public information content between English and any Indian language.**

# %% [markdown]
# ## Step 1: Install Required Libraries
#
# In this step, we install necessary libraries:
# - transformers → for loading pre-trained models
# - torch → for deep learning computations
# - sentencepiece → for tokenization

# %%
# !pip install transformers torch sentencepiece
# Out:
# Requirement already satisfied: transformers in c:\users\nitin\anaconda3\lib\site-packages (5.0.0)
# Requirement already satisfied: torch in c:\users\nitin\anaconda3\lib\site-packages (2.10.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.1-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: filelock in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (1.3.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\nitin\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nitin\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\nitin\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nitin\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.27.0)
# Requirement already satisfied: shellingham in c:\users\nitin\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\nitin\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\nitin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.2.0)
# Requirement already satisfied: certifi in c:\users\nitin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\nitin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.2)
# Requirement already satisfied: idna in c:\users\nitin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.7)
# Requirement already satisfied: sniffio in c:\users\nitin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\nitin\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.14.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\nitin\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\nitin\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\nitin\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\nitin\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nitin\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\nitin\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nitin\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\nitin\anaconda3\lib\site-packages (from typer-slim->transformers) (8.1.7)
# Downloading sentencepiece-0.2.1-cp312-cp312-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 1.8 MB/s  0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.1
# WARNING: Ignoring invalid distribution ~ip (C:\Users\nitin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\nitin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\nitin\anaconda3\Lib\site-packages)

# %% [markdown]
# ## Step 2: Import Required Modules
#
# We import:
# - AutoTokenizer → converts text to tokens (numbers)
# - AutoModelForSeq2SeqLM → loads translation model
# - torch → tensor operations

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# %% [markdown]
# ## Step 3: Load Pre-trained Translation Model
#
# We use the Helsinki English-Hindi translation model.
# This is a Transformer-based encoder-decoder model.
#
# Encoder → Reads English sentence
# Decoder → Generates Hindi sentence

# %%
model_name = "Helsinki-NLP/opus-mt-en-hi"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

print("Model Loaded Successfully 🚀")
# Out:
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Model Loaded Successfully 🚀

# %% [markdown]
# ## Step 4: Tokenization (Text → Numbers)
#
# Neural networks understand numbers, not words.
#
# Tokenizer:
# - Breaks sentence into subword tokens
# - Converts them into token IDs

# %%
sentence = "India is a diverse country."

inputs = tokenizer(sentence, return_tensors="pt")

print("Token IDs:")
print(inputs["input_ids"])

print("\nDecoded back to text:")
print(tokenizer.decode(inputs["input_ids"][0]))
# Out:
# Token IDs:
# tensor([[ 4535,    23,    19, 13938,  2126,     3,     0]])
#
# Decoded back to text:
# India is a diverse country.</s>

# %% [markdown]
# ## Step 5: Generate Translation
#
# The model:
# 1. Takes tokenized input
# 2. Passes through encoder
# 3. Decoder predicts output tokens
# 4. Generate method performs beam search decoding

# %%
outputs = model.generate(**inputs)

print("Generated Token IDs:")
print(outputs)
# Out:
# Generated Token IDs:
# tensor([[61949,  5682,  6962,    12,  1391,   153,     5,    14,     0]])

# %% [markdown]
# ## Step 6: Decode Output Tokens
#
# We convert predicted token IDs back to readable Hindi text.

# %%
translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("Original Sentence:")
print(sentence)

print("\nTranslated Sentence:")
print(translated_text)
# Out:
# Original Sentence:
# India is developing rapidly.
#
# Translated Sentence:
# भारत तेज़ी से बढ़ रहा है ।

# %% [markdown]
# ## Step 7: Create Translation Function
#
# This function wraps the full process:
# - Tokenize
# - Generate
# - Decode

# %%
def translate(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True)
    outputs = model.generate(**inputs)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %% [markdown]
# ## Step 8: Translate Custom Input
#
# User can enter any English public information text.

# %%
user_text = input("Enter English text: ")

print("\nTranslated Text:")
print(translate(user_text))
# Out:
# Translated Text:
# मैं एक आर्टिक विद्यार्थी हूँ

# %%
user_text = input("Enter English text: ")

print("\nOriginal Text:")
print(user_text)

print("\nTranslated Text:")
print(translate(user_text))
# Out:
# Original Text:
# I Am Going To Pune
#
# Translated Text:
# मैं पुने के लिए जा रहा हूँ

# %% [markdown]
# ## Conclusion
#
# This notebook successfully implements a Neural Machine Translation system
# using a Transformer-based pre-trained model.
#
# The system:
# - Converts English text to Hindi
# - Uses deep learning architecture
# - Demonstrates practical NLP application
